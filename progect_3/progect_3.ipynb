# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию" data-toc-modified-id="Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Откройте файл с данными и изучите общую информацию</a></span><ul class="toc-item"><li><span><a href="#Загрузите-данные-из-файла-в-датафрейм." data-toc-modified-id="Загрузите-данные-из-файла-в-датафрейм.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузите данные из файла в датафрейм.</a></span></li><li><span><a href="#Изучите-общую-информацию-о-полученном-датафрейме." data-toc-modified-id="Изучите-общую-информацию-о-полученном-датафрейме.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Изучите общую информацию о полученном датафрейме.</a></span></li><li><span><a href="#Постройте-общую-гистограмму-для-всех-числовых-столбцов-таблицы.-Например,-для-датафрейма-data-это-можно-сделать-командой-data.hist(figsize=(15,-20))." data-toc-modified-id="Постройте-общую-гистограмму-для-всех-числовых-столбцов-таблицы.-Например,-для-датафрейма-data-это-можно-сделать-командой-data.hist(figsize=(15,-20)).-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Постройте общую гистограмму для всех числовых столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Найдите-и-изучите-пропущенные-значения-в-столбцах:" data-toc-modified-id="Найдите-и-изучите-пропущенные-значения-в-столбцах:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Найдите и изучите пропущенные значения в столбцах:</a></span></li><li><span><a href="#Рассмотрите-типы-данных-в-каждом-столбце" data-toc-modified-id="Рассмотрите-типы-данных-в-каждом-столбце-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Рассмотрите типы данных в каждом столбце</a></span></li><li><span><a href="#Изучите-уникальные-значения-в-столбце-с-названиями-и-устраните-неявные-дубликаты.-Например,-«поселок-Рябово»-и-«поселок-городского-типа-Рябово»,-«поселок-Тельмана»-и-«посёлок-Тельмана»-—-это-обозначения-одних-и-тех-же-населённых-пунктов.-Вы-можете-заменить-названия-в-существующем-столбце-или-создать-новый-с-названиями-без-дубликатов." data-toc-modified-id="Изучите-уникальные-значения-в-столбце-с-названиями-и-устраните-неявные-дубликаты.-Например,-«поселок-Рябово»-и-«поселок-городского-типа-Рябово»,-«поселок-Тельмана»-и-«посёлок-Тельмана»-—-это-обозначения-одних-и-тех-же-населённых-пунктов.-Вы-можете-заменить-названия-в-существующем-столбце-или-создать-новый-с-названиями-без-дубликатов.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.</a></span></li><li><span><a href="#Найдите-и-устраните-редкие-и-выбивающиеся-значения.-Например,-в-столбце-ceiling_height-может-быть-указана-высота-потолков-25-м-и-32-м.-Логично-предположить,-что-на-самом-деле-это-вещественные-значения:-2.5-м-и-3.2-м.-Попробуйте-обработать-аномалии-в-этом-и-других-столбцах." data-toc-modified-id="Найдите-и-устраните-редкие-и-выбивающиеся-значения.-Например,-в-столбце-ceiling_height-может-быть-указана-высота-потолков-25-м-и-32-м.-Логично-предположить,-что-на-самом-деле-это-вещественные-значения:-2.5-м-и-3.2-м.-Попробуйте-обработать-аномалии-в-этом-и-других-столбцах.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.</a></span></li></ul></li><li><span><a href="#Шаг-3.-Добавьте-в-таблицу-новые-столбцы" data-toc-modified-id="Шаг-3.-Добавьте-в-таблицу-новые-столбцы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Добавьте в таблицу новые столбцы</a></span></li><li><span><a href="#Шаг-4.-Проведите-исследовательский-анализ-данных:" data-toc-modified-id="Шаг-4.-Проведите-исследовательский-анализ-данных:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Проведите исследовательский анализ данных:</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры-объектов:" data-toc-modified-id="Изучите-следующие-параметры-объектов:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры объектов:</a></span></li><li><span><a href="#Изучите,-как-быстро-продавались-квартиры-(столбец-days_exposition).-Этот-параметр-показывает,-сколько-дней-было-размещено-каждое-объявление." data-toc-modified-id="Изучите,-как-быстро-продавались-квартиры-(столбец-days_exposition).-Этот-параметр-показывает,-сколько-дней-было-размещено-каждое-объявление.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-общую-(полную)-стоимость-объекта?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-общую-(полную)-стоимость-объекта?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Какие факторы больше всего влияют на общую (полную) стоимость объекта?</a></span></li><li><span><a href="#Посчитайте-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-квадратного-метра.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Посчитайте-среднюю-цену-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-квадратного-метра.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Ранее-вы-посчитали-расстояние-до-центра-в-километрах.-Теперь-выделите-квартиры-в-Санкт-Петербурге-с-помощью-столбца-locality_name-и-вычислите-среднюю-цену-каждого-километра.-Опишите,-как-стоимость-объектов-зависит-от-расстояния-до-центра-города." data-toc-modified-id="Ранее-вы-посчитали-расстояние-до-центра-в-километрах.-Теперь-выделите-квартиры-в-Санкт-Петербурге-с-помощью-столбца-locality_name-и-вычислите-среднюю-цену-каждого-километра.-Опишите,-как-стоимость-объектов-зависит-от-расстояния-до-центра-города.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.</a></span></li></ul></li><li><span><a href="#Шаг-5.-Напишите-общий-вывод" data-toc-modified-id="Шаг-5.-Напишите-общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Напишите общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# ### Загрузите данные из файла в датафрейм.

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %% [markdown]
# ### Изучите общую информацию о полученном датафрейме.

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Обрати внимание, что часть столбцов заменилась на "...". Чтобы это исправить, нужно увеличить максимальное количество отображающихся столбцов командой
#
# 	pd.set_option('display.max_columns', None)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо, дабавил выше.
# </div>

# %% [markdown]
# При первом осмотре данных видно, что в некоторых колонка присутствуют пропуски, а сами названия колонок оформлены в разном стиле.

# %% [markdown]
# ### Постройте общую гистограмму для всех числовых столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).

# %%
df.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если после кода вызывающего график добавить ";", то мы избавимся от строчки над графиком)
#
# 	data.hist(figsize=(15, 20));
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Спасибо, добавил.
# </div>

# %%
df.describe(include='all')
# Out:
#         total_images    last_price    total_area first_day_exposition  \
# count   23699.000000  2.369900e+04  23699.000000                23699
# unique           NaN           NaN           NaN                 1491
# top              NaN           NaN           NaN  2018-02-01T00:00:00
# freq             NaN           NaN           NaN                  368
# mean        9.858475  6.541549e+06     60.348651                  NaN
# std         5.682529  1.088701e+07     35.654083                  NaN
# min         0.000000  1.219000e+04     12.000000                  NaN
# 25%         6.000000  3.400000e+06     40.000000                  NaN
# 50%         9.000000  4.650000e+06     52.000000                  NaN
# 75%        14.000000  6.800000e+06     69.900000                  NaN
# max        50.000000  7.630000e+08    900.000000                  NaN
#
#                rooms  ceiling_height  floors_total   living_area  \
# ...

# %% [markdown]
# ### Вывод
#
# Из первого осмотра данных видно, что необходимо:
# - привести название колонок к единообразию:
#         `cityCenters_nearest`;
#         `parks_around3000`;
#         `ponds_around3000`.
# - изменить тип данных в колонках:
#         `first_day_exposition` изменить на datatime;
#         `is_apartment` изменить на bool;
#         `balcony` изменить на int;
#         `parks_around3000` изменить на int;
#         `ponds_around3000` изменить на int;
# - заполнить пропуски в колонках:
#         `ceiling_height`;
#         `living_area`;
#         `is_apartment`;
#         `kitchen_area`;
#         `balcony`;
#         `locality_name`;
#         `airports_nearest`;
#         `cityCenters_nearest`;
#         `parks_around3000`;
#         `parks_nearest`;
#         `ponds_around3000`;
#         `ponds_nearest`;
#         `days_exposition`.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Рекомендую создать универсальную функцию, которая будет на вход принимать датафрейм, а на выходе будет выводить все необходимые характеристики поочередно применяя методы head, describe, info, duplicated и т.п.
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# Привожу название колонок к единообразию.

# %%
df = df.rename(columns = {'cityCenters_nearest': 'city_centers_nearest',
                          'parks_around3000' : 'parks_around_3000',
                         'ponds_around3000' : 'ponds_around_3000'})

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец! Так датафрейм будет более аккуратным
# </div>

# %% [markdown]
# ### Найдите и изучите пропущенные значения в столбцах:

# %% [markdown]
# - Определите, в каких столбцах есть пропуски.

# %% [markdown]
# Процент пропущеных значений в колонках.

# %%
round(df.isna().sum()/df.shape[0]*100, 1)
# Out:
# total_images             0.0
# last_price               0.0
# total_area               0.0
# first_day_exposition     0.0
# rooms                    0.0
# ceiling_height          38.8
# floors_total             0.4
# living_area              8.0
# floor                    0.0
# is_apartment            88.3
# studio                   0.0
# open_plan                0.0
# kitchen_area             9.6
# balcony                 48.6
# locality_name            0.2
# airports_nearest        23.4
# city_centers_nearest    23.3
# parks_around_3000       23.3
# parks_nearest           65.9
# ponds_around_3000       23.3
# ponds_nearest           61.6
# days_exposition         13.4
# dtype: float64

# %% [markdown]
# Видно что в датасете много колонок с пропусками. Исходя из названий колонок предположу,что не все пропуски нужно будет заполнить. В колонках `ponds_nearest, parks_nearest` оставлю пустые значения, вероятно такие квартиры не расположены в близком расстоянии от парков и прудов.

# %% [markdown]
# - Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски правильно заменить на 0. Если логичную замену предложить невозможно, то оставьте эти значения пустыми. Пропуски — тоже важный сигнал, который нужно учитывать.

# %%
(df[['balcony',
    'parks_around_3000',
    'ponds_around_3000']]) = (df[['balcony',
                              'parks_around_3000', 
                              'ponds_around_3000']].fillna(0))

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Пердполагаю что не заполнение данных в столбцах `balcony`,`parks_around3000`, `ponds_around3000` предполагает 0. Столбец is_apartment имеет булевые значения, не заполненные значения меняю на `False`. Предполагаю, что причиной не заполнения данных столбцов был человеческий фактор, отказ или пропуск в заполнении.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# В столбце `locality_name` удаляю не заполненные строки ввиду малого их количества они не окажут значимого влияния на иследование.

# %%
print(f"всего значений {df['locality_name'].count()},пустых строк {df['locality_name'].isna().sum()}")
df.dropna(subset=['locality_name'], inplace=True)
df = df.reset_index(drop=True)
# Out:
# всего значений 23650,пустых строк 49

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Удалить пропуски в столбце locality_name - это хорошее решение.
# </div>

# %% [markdown]
# Пустые значения в колонке `ceiling_height` заполняю медианным значением. Явно ошибочные значения меняю на логично подходящие, причины ошибок считаю человеческий фактор, опечатки. Значения менее 2 метров и более 4 метров заменяю на медианное и среднее значение.

# %%
list(df['ceiling_height'].sort_values(ascending=True).unique())
# Out:
# [1.0,
#  1.2,
#  1.75,
#  2.0,
#  2.2,
#  2.25,
#  2.3,
#  2.34,
#  2.4,
#  2.45,
#  2.46,
#  2.47,
#  2.48,
#  2.49,
#  2.5,
#  2.51,
#  2.52,
#  2.53,
#  2.54,
#  2.55,
#  2.56,
#  2.57,
#  2.58,
#  2.59,
#  2.6,
#  2.61,
#  2.62,
#  2.63,
#  2.64,
#  2.65,
#  2.66,
#  2.67,
#  2.68,
#  2.69,
#  2.7,
#  2.71,
#  2.72,
#  2.73,
#  2.74,
#  2.75,
#  2.76,
#  2.77,
#  2.78,
#  2.79,
#  2.8,
#  2.81,
#  2.82,
#  2.83,
#  2.84,
#  2.85,
#  2.86,
#  2.87,
#  2.88,
#  2.89,
#  2.9,
#  2.91,
#  2.92,
#  2.93,
#  2.94,
#  2.95,
#  2.96,
#  2.97,
#  2.98,
#  2.99,
#  3.0,
#  3.01,
#  3.02,
#  3.03,
#  3.04,
#  3.05,
#  3.06,
#  3.07,
#  3.08,
#  3.09,
#  3.1,
#  3.11,
#  3.12,
#  3.13,
#  3.14,
#  3.15,
#  3.16,
#  3.17,
#  3.18,
#  3.2,
#  3.21,
#  3.22,
#  3.23,
#  3.24,
#  3.25,
#  3.26,
#  3.27,
#  3.28,
#  3.29,
#  3.3,
#  3.31,
#  3.32,
#  3.33,
#  3.34,
#  3.35,
#  3.36,
#  3.37,
#  3.38,
#  3.39,
#  3.4,
#  3.42,
#  3.43,
#  3.44,
#  3.45,
#  3.46,
#  3.47,
#  3.48,
#  3.49,
#  3.5,
# ...

# %%
ceiling_height_median = df['ceiling_height'].median()
df['ceiling_height'].fillna(ceiling_height_median, inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# Пропуски в колонках `kitchen_area` и `living_area` заполняю медианным значением из сгрупированных данных по количеству комнат в квартире.

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df.groupby('rooms')['kitchen_area'].transform('median'))

# %%
df['living_area'] = df['living_area'].fillna(df.groupby('rooms')['living_area'].transform('median'))

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Хороший способ)
# </div>

# %% [markdown]
# Оставшиеся пустые значения заполняю медианным значением от всего столбца данных.

# %%
#df['kitchen_area'] = df['kitchen_area'].fillna(df['kitchen_area'].median())

# %%
#df['living_area'] = df['living_area'].fillna(df['living_area'].median())

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>В  таком случае, нужно проверить чтобы жилая площадь и площадь кухни не была больше общей. Эти пропуски можно вообще не заполнять
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Решил закомментировать строчки выше с медианым заполнением пропусков.
# </div>

# %% [markdown]
# Заполняю пропуски в стобце `floors_total` медианным значением сгрупированным по месторасположению квартиры.

# %%
#groupby_floors_total = df.groupby('locality_name')['floors_total'].transform('median')
#df['floors_total'] = df['floors_total'].fillna(groupby_floors_total)

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если мы заполняем таким способом, то нужно делать проверку, а не превышает ли этаж, на котором квартира общую этажность? Можно заменить на этаж квартиры либо оставить как есть
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Оставил пропуски. Старый код закомментировал.
# </div>

# %% [markdown]
# Заполняю пропуски в стобцах `airports_nearest` и `cityCenters_nearest` средним значением расстояния сгрупированным по месторасположению квартиры.

# %%
groupby_airpots_nearest = df.groupby('locality_name')['airports_nearest'].transform('mean')
df['airports_nearest'] = df['airports_nearest'].fillna(groupby_airpots_nearest)

# %% [markdown]
# Оставшиеся пустые значения заполняю средним значением от всего столбца данных.

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(df['airports_nearest'].mean())

# %%
groupby_city_centers_nearest = df.groupby('locality_name')['city_centers_nearest'].transform('mean')
df['city_centers_nearest'] = df['city_centers_nearest'].fillna(groupby_city_centers_nearest)

# %% [markdown]
# Оставшиеся пустые значения заполняю средним значением от всего столбца данных.

# %%
#df['city_centers_nearest'] = df['city_centers_nearest'].fillna(df['city_centers_nearest'].mean())

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбцах с картографическими данными лучше не трогать. Заполняя их таким образом, ты проставляешь одинаковые расстояния до центра (парка, прудов, аэропорта) для разных квартир, хотя они могут быть расположены в разных частях города. Эти пропуски заполнять не нужно
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Закомментировал строку с кодом выше, что бы код в ней не влиял на результат.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# Столбец `days_exposition` является важным для аназиза пропуски в нем придется удалить, так как эти данные являются ключевыми для анализа.

# %%
#df = df.dropna(subset=['days_exposition'])
#df = df.reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Удаляя тут пропуски, ты теряешь данные в других столбцах. Делать этого не нужно)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Закомментировал строку с кодом выше, что бы код в ней не влиял на результат.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# В колонках `ponds_nearest`, `parks_nearest` оставлю пустые значения, вероятно такие квартиры не расположены в близком расстоянии от парков и прудов.

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               85
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              197
# balcony                     0
# locality_name               0
# airports_nearest            0
# city_centers_nearest     5386
# parks_around_3000           0
# parks_nearest           15586
# ponds_around_3000           0
# ponds_nearest           14565
# days_exposition          3180
# dtype: int64

# %% [markdown]
# - В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.

# %% [markdown]
# Сделаю предположение о том что в колонках с расстоянием `airports_nearest`, `city_centers_nearest`, `parks_around_3000`, `parks_nearest`, `ponds_around_3000`, `ponds_nearest` автоматически на основе неких данных о месторасположении квартир. Пропуски появились в результате сбоя или отсутсвия этих данных. В колонке `is_apartment` пропуски вероятно появились по причине не заполнения данных, в датасете есть данные с 2014 года, когда апартоменты были еще не распростанены. В остальных колонка вероятно имела место быть ошибка в заполнении от пользователей.

# %% [markdown]
# ### Рассмотрите типы данных в каждом столбце

# %% [markdown]
# - Найдите столбцы, в которых нужно изменить тип данных.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23650 entries, 0 to 23649
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23650 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          23453 non-null  float64
#  13  balcony               23650 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# - Преобразуйте тип данных в выбранных столбцах.

# %% [markdown]
# Изменяю тип данных в столбцах `floors_total`, `balcony`, `airports_nearest`, `city_centers_nearest`, `days_exposition` с `float` на `int`.

# %%
#df['floors_total'] = df['floors_total'].astype('int')
#df['balcony'] = df['balcony'].astype('int')
#df['airports_nearest'] = df['airports_nearest'].astype('int')
#df['city_centers_nearest'] = df['city_centers_nearest'].astype('int')
#df['parks_around_3000'] = df['parks_around_3000'].astype('int')
#df['ponds_around_3000'] = df['ponds_around_3000'].astype('int')
#df['days_exposition'] = df['days_exposition'].astype('int')
df.astype({'balcony':'int','airports_nearest':'int','parks_around_3000':'int','ponds_around_3000':'int'}).dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment               bool
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                   int64
# locality_name            object
# airports_nearest          int64
# city_centers_nearest    float64
# parks_around_3000         int64
# parks_nearest           float64
# ponds_around_3000         int64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Методы fillna и astype можно применить к нескольким столбюца одновременно
#
# 	df.astype({ "col1": "float64", "col2": "int64"})
# <br>Если столбцов более двух, то можно применить цикл for для автоматизации процесса
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Старый код закомментировал, добавил df.astype через словарь.
# </div>

# %% [markdown]
# В столбце `first_day_exposition`  тип данных `object`, хотя данные в нем относятся к дате и времени. Меняем тип данных на время.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format ='%Y-%m-%d' )

# %% [markdown]
# - В ячейке с типом markdown поясните, почему нужно изменить тип данных.

# %% [markdown]
# Тип данных в колонке `first_day_exposition` не соответствует находящимся в нем данным. В колонках `floors_total, floor, balcony, airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000, days_exposition` данные представлены целочисленными значениями. Тип данных в этих колонках лучше мзменить на  int.

# %% [markdown]
# ### Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.

# %% [markdown]
# Определяю уникальные значения в столбце `locality_name`.

# %%
list(df['locality_name'].unique())
# Out:
# ['Санкт-Петербург',
#  'посёлок Шушары',
#  'городской посёлок Янино-1',
#  'посёлок Парголово',
#  'посёлок Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'деревня Кудрово',
#  'Коммунар',
#  'Колпино',
#  'поселок городского типа Красный Бор',
#  'Гатчина',
#  'поселок Мурино',
#  'деревня Фёдоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'деревня Новое Девяткино',
#  'посёлок Металлострой',
#  'посёлок городского типа Лебяжье',
#  'посёлок городского типа Сиверский',
#  'поселок Молодцово',
#  'поселок городского типа Кузьмоловский',
#  'садовое товарищество Новая Ропша',
#  'Павловск',
#  'деревня Пикколово',
#  'Всеволожск',
#  'Волхов',
#  'Кингисепп',
#  'Приозерск',
#  'Сестрорецк',
#  'деревня Куттузи',
#  'посёлок Аннино',
#  'поселок городского типа Ефимовский',
#  'посёлок Плодовое',
#  'деревня Заклинье',
#  'поселок Торковичи',
#  'поселок Первомайское',
#  'Красное Село',
#  'посёлок Понтонный',
#  'Сясьстрой',
#  'деревня Старая',
# ...

# %% [markdown]
# В столбце присутствует множество неявных дубликатов. Для придания единообразия оставим только то, что начинается с большой буквы во всем столбце.

# %%
def up(string):
    for i in range(len(string)):
        if string[i].isupper():
            return string[i: len(string)]

# %%
df['locality_name'] = df['locality_name'].apply(up)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# ### Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.

# %% [markdown]
# - Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение

# %%
df['ceiling_height'] = df['ceiling_height'].replace({26 : 2.6,
                                                    27 : 2.7,
                                                    32 : 3.2,
                                                    25 : 2.5,
                                                    24 : 2.4,
                                                    27.5 : 2.75})

# %% [markdown]
# - В противном случае удалите редкие и выбивающиеся значения.

# %%
df.loc[df['ceiling_height'] < 2, 'ceiling_height'] = df['ceiling_height'].median()
df.loc[df['ceiling_height'] > 4, 'ceiling_height'] = df['ceiling_height'].median()

# %% [markdown]
# - В ячейке с типом markdown опишите, какие особенности в данных вы обнаружили.

# %% [markdown]
# **Вывод**
# В столбце `ceiling_height` присутствовали выбросы данных. Присутствовали как черезмерно низкие показатели высоты потолков в квартирах так и черезмерно высокие. Причинами вероятно могли быть ошибки в заполнении. Такие выделяющиеся значения были заменены медианным значение из всего столбца.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Диапазоны для аномальных значений подобраны и удалены верно!
# </div>

# %% [markdown]
# ## Шаг 3. Добавьте в таблицу новые столбцы

# %% [markdown]
# - цена одного квадратного метра;

# %%
df['one_meter_price'] = (df['last_price'] / df['total_area']).round(0)

# %% [markdown]
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);

# %%
df['day_of_publication'] = df['first_day_exposition'].dt.weekday

# %% [markdown]
# - месяц публикации объявления;

# %%
df['month_of_publication'] = df['first_day_exposition'].dt.month

# %% [markdown]
# - год публикации объявления;

# %%
df['year_of_publication'] = df['first_day_exposition'].dt.year

# %% [markdown]
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);

# %%
def kind_floor(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    else:
        return 'другой'
    
df['kind_floor'] = df.apply(kind_floor, axis = 1)

# %% [markdown]
# - расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# %%
df['city_centers_nearest_km'] = (df['city_centers_nearest'] / 1000).round(0)

# %% [markdown]
# **Вывод**
#
# В датасет были добавлены столбцы: стоимость одного квадратного метра, день недели публикации,месяц публикации,год публикации, тип этажа квартиры и растояние до цента города в километрах.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ## Шаг 4. Проведите исследовательский анализ данных:

# %% [markdown]
# ### Изучите следующие параметры объектов:

# %% [markdown]
# - Общая площадь;

# %%
df.boxplot(column = ['total_area'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Присутствуют выбросы данных. Сокращаю выборку до 130 квадратных метров.

# %%
df = df.query('total_area < 130')

# %%
df['total_area'].hist(bins=100,color='#222267', range=(0, 130), figsize=(15, 5))
plt.axvline(df['total_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['total_area'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Площадь квартиры в квадратных метрах (м²)')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно занимаемой площади')
plt.show()

# %%
df['total_area'].describe()
# Out:
# count    22791.000000
# mean        55.453667
# std         21.034168
# min         12.000000
# 25%         39.800000
# 50%         50.900000
# 75%         66.900000
# max        129.800000
# Name: total_area, dtype: float64

# %% [markdown]
# На графике половину занимают квартиры до 50 квадратных метров площади.

# %% [markdown]
# - жилая площадь;

# %%
df.boxplot(column = ['living_area'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Присутствуют выбросы данных. Сокращаю выборку до 77 квадратных метров.

# %%
df = df.query('living_area <= 77')

# %%
df['living_area'].hist(bins=50,color='#222267', range=(0, 77), figsize=(15, 5))
plt.axvline(df['living_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['living_area'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Жилая площадь квартиры в квадратных метрах (м²)')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно занимаемой жилой площади')
plt.show()

# %%
df['living_area'].describe()
# Out:
# count    22619.000000
# mean        31.221016
# std         13.568140
# min          2.000000
# 25%         18.000000
# 50%         30.000000
# 75%         40.700000
# max         77.000000
# Name: living_area, dtype: float64

# %% [markdown]
# На графике половину числа квартик по жилой площади занимают квартиры до 30 метров квадратных. из них преобладают квартиры с метражем жилой площади до 18 метров квадратных.

# %% [markdown]
# - площадь кухни;

# %%
df.boxplot(column = ['kitchen_area'])
# Out:
# <AxesSubplot:>

# %%
df = df.query('3 < kitchen_area <= 18')

# %%
df['kitchen_area'].hist(bins=100,color='#222267', range=(3, 18), figsize=(15, 5))
plt.axvline(df['kitchen_area'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['kitchen_area'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Площадь кухни в квадратных метрах (м²)')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно площади кухни')
plt.show()

# %%
df['kitchen_area'].describe()
# Out:
# count    21466.000000
# mean         9.300925
# std          2.792567
# min          3.200000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         18.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Среднее и медианное значение площади кухон в продоваемых квартира практически совпадает и находится на уровне 9 метров квадратных.

# %% [markdown]
# - цена объекта;

# %%
df.boxplot(column = ['last_price'])
# Out:
# <AxesSubplot:>

# %%
df['last_price'].hist(bins=100,range=(0, 15000000),color='#222267', figsize=(15, 5))
plt.axvline(df['last_price'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['last_price'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Цена квартир на момент снятия с публикации')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно цены на момент снятия с публикации')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут можно разделить все значения в столбце last_price на 1 млн, чтобы они пришли в более понятный вид)
# </div>

# %%
df['last_price'].describe()
# Out:
# count    2.146600e+04
# mean     5.175753e+06
# std      3.186964e+06
# min      4.300000e+05
# 25%      3.350000e+06
# 50%      4.490000e+06
# 75%      6.150000e+06
# max      5.300000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# Из графика видно,чтоцена на большую часть квартир лежит в промежутке от 3.3 млн до 5.96 млн.

# %% [markdown]
# - количество комнат;

# %%
df.boxplot(column = ['rooms'])
# Out:
# <AxesSubplot:>

# %%
df['rooms'].hist(bins=30,color='#222267', range=(0, 5), figsize=(15, 5))
plt.axvline(df['rooms'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['rooms'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Число комнат в квартирах')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно числа комнат')
plt.show()

# %%
df['rooms'].describe()
# Out:
# count    21466.000000
# mean         1.959331
# std          0.887459
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# По количеству комнат преобладают двухкомнатные квартиры.

# %% [markdown]
# - высота потолков;

# %%
df.boxplot(column = ['ceiling_height'])
# Out:
# <AxesSubplot:>

# %%
df['ceiling_height'].hist(bins=10,color='#222267', range=(2, 4), figsize=(15, 5))
plt.axvline(df['ceiling_height'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['ceiling_height'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Высота потолков в квартирах (м)')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно высоты потолков в квартирах')
plt.show()

# %%
df['ceiling_height'].describe()
# Out:
# count    21466.000000
# mean         2.673656
# std          0.177678
# min          2.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В среднем высота потолков в квартирах 2.6 м.

# %% [markdown]
# - этаж квартиры;

# %%
df.boxplot(column = ['floor'])
# Out:
# <AxesSubplot:>

# %%
df['floor'].hist(bins=100,color='#222267', range=(0, 25), figsize=(15, 5))
plt.axvline(df['floor'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['floor'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Этаж квартиры')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно этажа квартиры')
plt.show()

# %%
df['floor'].describe()
# Out:
# count    21466.000000
# mean         5.869515
# std          4.858825
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Из графика видно, что большая часть квартир в обьявлениях находся до 8 этажа.

# %% [markdown]
# - тип этажа квартиры («первый», «последний», «другой»);

# %%
df['kind_floor'].hist(bins=100,color='#222267', figsize=(15, 5))
plt.xlabel('Тип этажа квартиры')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно тмпа этажа квартиры')
plt.show()

# %%
df['kind_floor'].describe()
# Out:
# count      21466
# unique         3
# top       другой
# freq       15759
# Name: kind_floor, dtype: object

# %% [markdown]
# - общее количество этажей в доме;

# %%
df.boxplot(column = ['floors_total'])
# Out:
# <AxesSubplot:>

# %%
df['floors_total'].hist(bins=50,color='#222267', range=(0, 40), figsize=(15, 5))
plt.axvline(df['floors_total'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['floors_total'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Этажей в доме')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно этажей в доме')
plt.show()

# %%
df['floors_total'].describe()
# Out:
# count    21391.000000
# mean        10.700061
# std          6.570421
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# График указывает на то что квартиры в основном находятся в 5 - 9 этажных домах.

# %% [markdown]
# - расстояние до центра города в метрах;

# %%
df.boxplot(column = ['city_centers_nearest'])
# Out:
# <AxesSubplot:>

# %%
df['city_centers_nearest'].hist(bins=50,color='#222267', range=(0, 35000), figsize=(15, 5))
plt.axvline(df['city_centers_nearest'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['city_centers_nearest'].mean(), color='orange', linestyle='--', label='mean')
plt.axhline(df['city_centers_nearest'].count() / 20, color='g', linestyle='-.', label='unified count')
plt.xlabel('расстояние до центра города в метрах')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно расстояния до центра города в метрах')
plt.show()

# %%
df['city_centers_nearest'].describe()
# Out:
# count    16298.000000
# mean     14826.619469
# std       8552.841062
# min        208.000000
# 25%      10372.250000
# 50%      13478.500000
# 75%      16638.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находятся на 15 км отдалении от центра.

# %% [markdown]
# - расстояние до ближайшего аэропорта;

# %%
df.boxplot(column = ['airports_nearest'])
# Out:
# <AxesSubplot:>

# %%
df['airports_nearest'].hist(bins=25,color='#222267', range=(0, 90000), figsize=(15, 5))
plt.axvline(df['airports_nearest'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['airports_nearest'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('расстояние до ближайшего аэропорта')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно расстояние до ближайшего аэропорта')
plt.show()

# %%
df['airports_nearest'].describe()
# Out:
# count    21466.000000
# mean     28974.565552
# std      11301.671717
# min          0.000000
# 25%      20888.250000
# 50%      28879.458401
# 75%      34947.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находится на 30 километровом удалении от аэропорта.

# %% [markdown]
# - расстояние до ближайшего парка;

# %%
df.boxplot(column = ['parks_nearest'])
# Out:
# <AxesSubplot:>

# %%
df['parks_nearest'].hist(bins=25,color='#222267', range=(0, 3000), figsize=(15, 5))
plt.axvline(df['parks_nearest'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['parks_nearest'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('расстояние до ближайшего парка')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно расстояние до ближайшего парка')
plt.show()

# %%
df['parks_nearest'].describe()
# Out:
# count    6921.000000
# mean      491.856379
# std       337.074528
# min         1.000000
# 25%       289.000000
# 50%       456.000000
# 75%       615.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Из квартир находящихся в радиусе 3 км до ближайшего парка, этот парк в среднем находится в менее 500 метрах от квартиры.

# %% [markdown]
# - день и месяц публикации объявления;

# %%
df.boxplot(column = ['day_of_publication'])
# Out:
# <AxesSubplot:>

# %%
df['day_of_publication'].hist(bins=25,color='#222267', range=(0, 6), figsize=(15, 5))
plt.axvline(df['day_of_publication'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['day_of_publication'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('День публикации')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно дня публикации')
plt.show()

# %%
df['day_of_publication'].describe()
# Out:
# count    21466.000000
# mean         2.571415
# std          1.793861
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: day_of_publication, dtype: float64

# %% [markdown]
# Про дню публикации обьявления больше всего обьявлений публиковали в четверг.

# %%
df.boxplot(column = ['parks_nearest'])
# Out:
# <AxesSubplot:>

# %%
df['month_of_publication'].hist(bins=25,color='#222267', range=(1, 12), figsize=(15, 5))
plt.axvline(df['month_of_publication'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['month_of_publication'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('Месяц публикации')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно месяца публикации')
plt.show()

# %%
df['month_of_publication'].describe()
# Out:
# count    21466.000000
# mean         6.388242
# std          3.486237
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# Name: month_of_publication, dtype: float64

# %% [markdown]
# Больше всех оьявлений публиковалось в феврале.

# %% [markdown]
# **Вывод**
#
# Из расмотренных выше показателей можно сделать вывод, что в среднем в обьявлениях о продаже квартир представлены 1 - 2 комнатные квартиры, общей площадью до 50 квадратных метро. Цена на такие квартиры варьируется от 3 до 6 млн. Квартиры в среднем расположены в 5 - 9 этажных зданиях с удалением от центра города до 15 км.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики! Отдельный плюс за то, что ты подписываешь графики и их оси
# </div>

# %% [markdown]
# ### Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.

# %% [markdown]
# - Постройте гистограмму.

# %%
df['days_exposition'].hist(bins=25,color='#222267', range=(0, 1500), figsize=(15, 5))
plt.axvline(df['days_exposition'].median(), color='r', linestyle='--', label='median')
plt.axvline(df['days_exposition'].mean(), color='orange', linestyle='--', label='mean')
plt.xlabel('дни размещения обьявления')  
plt.ylabel('Количество квартир')  
plt.title('Распределение квартир относительно дней размещения обьявления')
plt.show()

# %% [markdown]
# - Посчитайте среднее и медиану.

# %%
df['days_exposition'].describe()
# Out:
# count    18750.000000
# mean       174.426080
# std        212.996348
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        221.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# - В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?

# %% [markdown]
# В среднем продажа квартиры занимает 173 дня, медиана 92 дня. Быстрыми можно считать продажи до 44, долгими до 219. К необычно долгим можно отнести продажи свыше 220 дней.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен! Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %% [markdown]
# ### Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#  Изучите, зависит ли цена от:

# %% [markdown]
# - общей площади;

# %%
df.plot(x='total_area', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# Цена пропоруиаонально зависит от площади квартиры.

# %% [markdown]
# - жилой площади;

# %%
df.plot(x='living_area', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %% [markdown]
# - площади кухни;

# %%
df.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %% [markdown]
# - количества комнат;

# %%
df.plot(x='rooms', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# - высота потолков;

# %%
df.plot(x='ceiling_height', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='ceiling_height', ylabel='last_price'>

# %% [markdown]
# - этаж квартиры;

# %%
df.plot(x='floor', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='floor', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Не изучено влияние категории этажа на стоимость квартиры
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# - этажа, на котором расположена квартира (первый, последний, другой);

# %%
day_price = df.pivot_table(index = 'kind_floor', values = 'last_price', aggfunc = 'mean')
day_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='kind_floor'>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Можно сделать вывод о том что квартиры на первых этажах обладают самой низкой стоимость. Их стоимость в среднем ниже чем у квартир на последнем этаже. Так же стоимость квартир на последних этажах ниже чем у квартир на других этажах.
# </div>

# %% [markdown]
# - общее количество этажей в доме;

# %%
df.plot(x='floors_total', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='floors_total', ylabel='last_price'>

# %% [markdown]
# - расстояние до центра города в метрах;

# %%
df.plot(x='city_centers_nearest', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='city_centers_nearest', ylabel='last_price'>

# %% [markdown]
# - расстояние до ближайшего аэропорта;

# %%
df.plot(x='airports_nearest', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='airports_nearest', ylabel='last_price'>

# %% [markdown]
# - расстояние до ближайшего парка;

# %%
df.plot(x='parks_nearest', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='parks_nearest', ylabel='last_price'>

# %% [markdown]
# - даты размещения (день недели, месяц, год).

# %%
df.plot(x='day_of_publication', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='day_of_publication', ylabel='last_price'>

# %%
df.plot(x='month_of_publication', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='month_of_publication', ylabel='last_price'>

# %%
df.plot(x='year_of_publication', y='last_price', kind='scatter', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='year_of_publication', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Для категории этажа, дня, месяца и года продажи нужно построить barplot рассчитав среднее значение или медиану. После этого необходимо написать о зависимости цены от этих параметров
#
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %%
day_price = df.pivot_table(index = 'day_of_publication', values = 'last_price', aggfunc = 'mean')
day_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='day_of_publication'>

# %%
day_price = df.pivot_table(index = 'month_of_publication', values = 'last_price', aggfunc = 'mean')
day_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='month_of_publication'>

# %%
day_price = df.pivot_table(index = 'year_of_publication', values = 'last_price', aggfunc = 'mean')
day_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='year_of_publication'>

# %%
day_price = df.pivot_table(index = 'year_of_publication', values = 'last_price', aggfunc = 'count')
day_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='year_of_publication'>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Средние значение за день и месяц находятся примерно на одинаковом уровне. В формате графика за год наблюдается снижение среднего значения цены от показателей 2014 года. Однако количество значений за 2014 год является наименьшим из всех годов наблюдения.
# </div>

# %% [markdown]
# - Постройте графики, которые покажут - зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.

# %%
df_corr = df[['total_area','living_area','kitchen_area','rooms','floor','last_price','day_of_publication',
             'month_of_publication','year_of_publication']]
df_corr.corr()
# Out:
#                       total_area  living_area  kitchen_area     rooms  \
# total_area              1.000000     0.907916      0.449089  0.796058
# living_area             0.907916     1.000000      0.206733  0.901640
# kitchen_area            0.449089     0.206733      1.000000  0.055256
# rooms                   0.796058     0.901640      0.055256  1.000000
# floor                  -0.012883    -0.122762      0.264621 -0.161088
# last_price              0.687593     0.554469      0.453776  0.402336
# day_of_publication     -0.010036    -0.006758     -0.011993  0.000142
# month_of_publication    0.009431    -0.000696      0.019462 -0.000046
# year_of_publication    -0.059086    -0.045773     -0.047556 -0.033036
#
#                          floor  last_price  day_of_publication  \
# total_area           -0.012883    0.687593           -0.010036
# living_area          -0.122762    0.554469           -0.006758
# kitchen_area          0.264621    0.453776           -0.011993
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Рассчитывать корреляцию Пирсона для категории этажа, дня, месяца и года продажи не эффективно, так как цена в данном случае зависит от них не линейно. Нужно удалить эти столбцы из таблицы с расчетом корреляции выше
# </div>

# %%
df_corr = df[['total_area','living_area','kitchen_area','rooms','last_price']]
df_corr.corr()
# Out:
#               total_area  living_area  kitchen_area     rooms  last_price
# total_area      1.000000     0.907916      0.449089  0.796058    0.687593
# living_area     0.907916     1.000000      0.206733  0.901640    0.554469
# kitchen_area    0.449089     0.206733      1.000000  0.055256    0.453776
# rooms           0.796058     0.901640      0.055256  1.000000    0.402336
# last_price      0.687593     0.554469      0.453776  0.402336    1.000000

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удалил указанные категории.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# **Вывод**
#
# Рассмотрев графики выше и таблицу корреляции можно сделать вывод, что из всех факторов на цену недвижимости влияет ее площадь. Графа с площадью квартиры имеет наибольшую корреляцию с графой цены. На графиках так же видно,что увеличения общей площа, жилой площади, площади кухни, количества комнат, год публикации оказывает влияние на цену. Графы относящиеся ко дню и месяцу публикации обьявлений практически не оказывают влияния.

# %% [markdown]
# ### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.

# %% [markdown]
# Посчитаем цену одного квадратного метра во всех обьявлениях.

# %%
df['mean_price_square_meter'] = df['last_price'] / df['total_area']

# %% [markdown]
# Определим 10 насёленных пунктов с наибольшим числом обьявлений.

# %%
df['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург    13878
# Мурино               544
# Шушары               429
# Кудрово              420
# Всеволожск           380
# Колпино              331
# Пушкин               330
# Парголово            313
# Гатчина              301
# Выборг               223
# Name: locality_name, dtype: int64

# %% [markdown]
# Выделяем населённые пункты с самой высокой стоимостью.

# %%
top_ten_table = df.pivot_table(index='locality_name', 
               values='mean_price_square_meter', 
               aggfunc=['count', 'mean']
               ).reset_index()
top_ten_table.columns = ['Населенный пункт', 'Число обьявлений', 'Стоимость квадратного метра']
top_ten_table.sort_values(['Число обьявлений'], ascending = False).head(10)
# Out:
#     Населенный пункт  Число обьявлений  Стоимость квадратного метра
# 219  Санкт-Петербург             13878                109259.500403
# 144           Мурино               544                 85603.686963
# 293           Шушары               429                 78387.601076
# 103          Кудрово               420                 95547.257099
# 34        Всеволожск               380                 68512.205847
# 87           Колпино               331                 75395.087691
# 198           Пушкин               330                100763.063324
# 168        Парголово               313                 90784.240957
# 42           Гатчина               301                 68803.418318
# 35            Выборг               223                 57895.343346

# %% [markdown]
# **Вывод**
#
# Санкт-Петербург сильно превосходит другие населенные пункты по количесву обьявлений и цене квадратного метра. Из 10 населенных пунутов с наибольшим количеством обьявлений Выборг обладает самой низкой ценой квадратного метра.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Всё верно! Как вариант, тут можно построить барплот для топ10, так будет более наглядно)
# </div>

# %% [markdown]
# ### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# Отфильтруем обьявления по городу Санкт-Петербург и посчитаем среднюю стоимость каждого километра.

# %%
df_spb = df.query('locality_name == "Санкт-Петербург"')
df_spb_plot = df_spb.groupby(by = 'city_centers_nearest_km').agg({'mean_price_square_meter':'mean'}).round()
df_spb_plot
# Out:
#                          mean_price_square_meter
# city_centers_nearest_km
# 0.0                                     151780.0
# 1.0                                     150352.0
# 2.0                                     142525.0
# 3.0                                     118037.0
# 4.0                                     124600.0
# 5.0                                     131377.0
# 6.0                                     131823.0
# 7.0                                     132112.0
# 8.0                                     121012.0
# 9.0                                     110991.0
# 10.0                                    110964.0
# 11.0                                    107168.0
# 12.0                                    107679.0
# 13.0                                    107181.0
# 14.0                                    103681.0
# 15.0                                    103031.0
# 16.0                                     99502.0
# 17.0                                     96105.0
# ...

# %%
df_spb_plot.plot(grid = True, figsize = (15,9))
# Out:
# <AxesSubplot:xlabel='city_centers_nearest_km'>

# %% [markdown]
# **Вывод**
#
# При приближении к центру города цена на графике возрастает.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>На каком километре заканчивается центр города на твой взгляд, судя по графику?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>На графике в районе 7 - 8 километра наблюдается устойчивый спад цены стоимости квадратного метра. Предположу, что центром можно считать промежуто от 0 до 8 километров.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Верно)
# </div>

# %% [markdown]
# ## Шаг 5. Напишите общий вывод

# %% [markdown]
# **Вывод**
#
# Больше всего квартир продают в Санкт-Петербурге, цена за квадратный метр так же является самой большой в этом городе. Из факторов влияющих на цену недвижимости самым влиятельным является её площадь и удаленность от центра города.
# Продажа квартиры в среднем занимает 173 дня, медиана 92 дня. Быстрыми можно считать продажи до 44, долгими до 219. К необычно долгим можно отнести продажи свыше 220 дней.
# В среднем в обьявлениях о продаже квартир представлены 1 - 2 комнатные квартиры, общей площадью до 50 квадратных метро. Цена на такие квартиры варьируется от 3 до 6 млн. Квартиры в среднем расположены в 5 - 9 этажных зданиях с удалением от центра города до 15 км.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай увеличим объем вывода, чтобы он получится более подробным. Хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. А после этого нужно написать общий вывод использую информацию из промежуточных выводов после каждого раздела. Твой вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудился, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- не заполнять пропуски в столбцах с картографическими данными
# <br>- не удалять пропуски в столбце days_exposition
# <br>- корректно изучить зависимость цены от категории этажа и времени публикации объявления
# <br>- удалить расчет корреляции для времени продажи
# <br>- дописать общий вывод
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div style="border:solid #d9eef7 3px; padding: 20px">
# Был проведён анализ входных данных сервиса Яндекс.Недвижимость.
#
# В процессе анализа были определены и заполнены столбцы с пропусками данных: ceiling_height; living_area; is_apartment; kitchen_area; balcony; locality_name; airports_nearest; cityCenters_nearest; parks_around3000; parks_nearest; ponds_around3000; ponds_nearest; days_exposition.
#
# Рассмотрены и изменены типы данных в столбцах: first_day_exposition изменить на datatime; is_apartment изменить на bool; balcony изменить на int; parks_around3000 изменить на int; ponds_around3000 изменить на int;
#
# Была проведена работа по устранению неявных дубликатов в столбце locality_name. Данные в столбце были приведены к единообразию.
#
# Были найдены и устранены редкие и выбивающиеся значения в столбце ceiling_height. Присутствовали как черезмерно низкие показатели высоты потолков в квартирах так и черезмерно высокие. Причинами вероятно могли быть ошибки в заполнении. Такие выделяющиеся значения были заменены медианным значение из всего столбца.
#
# Были расчита и добавлены в таблицу новые столбцы с данными:
#     • цена одного квадратного метра;
#     • день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
#     • месяц публикации объявления;
#     • год публикации объявления;
#     • тип этажа квартиры (значения — «первый», «последний», «другой»);
#     • расстояние до центра города в километрах.
#
# Изучены следующие параметры обьектов:
#     общая площадь;
#     жилая площадь;
#     площадь кухни;
#     цена объекта;
#     количество комнат;
#     высота потолков;
#     этаж квартиры;
#     тип этажа квартиры («первый», «последний», «другой»);
#     общее количество этажей в доме;
#     расстояние до центра города в метрах;
#     расстояние до ближайшего аэропорта;
#     расстояние до ближайшего парка; день и месяц публикации объявления.
#
# Из перечисленных параметров можно сделать вывод, что в среднем в обьявлениях о продаже квартир представлены 1 - 2 комнатные квартиры, общей площадью до 50 квадратных метро. Цена на такие квартиры варьируется от 3 до 6 млн. Квартиры в среднем расположены в 5 - 9 этажных зданиях с удалением от центра города до 15 км.
#
# Изучены данные о времени продажи квартир из столбца days_exposition.
#     В среднем продажа квартиры занимает 173 дня, медиана 92 дня. Быстрыми можно считать продажи до 44, долгими до 219. К необычно долгим можно отнести продажи свыше 220 дней.
#
# Изучена зависимость цены от следующих факторов:
#     общей площади;
#     жилой площади;
#     площади кухни;
#     количества комнат;
#     этажа, на котором расположена квартира (первый, последний, другой);
#     даты размещения (день недели, месяц, год).
# Из всех факторов на цену недвижимости влияет ее площадь. Графа с площадью квартиры имеет наибольшую корреляцию с графой цены. Увеличение общей площади, жилой площади, площади кухни, количества комнат, год публикации оказывает влияние на цену. Графы относящиеся ко дню и месяцу публикации обьявлений практически не оказывают влияния.
#
# Была расчитана средняя цена квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделены населенные пункты с самой высокой и самой низкой стоимостью.
#     Санкт-Петербург сильно превосходит другие населенные пункты по количесву обьявлений и цене квадратного метра. Из 10 населенных пунутов с наибольшим количеством обьявлений Выборг обладает самой низкой ценой квадратного метра.
#
# Была расcчитана стоимость расстояния каждого километра удаленности от центра города.
#  Рассчеты показали, что удаленность от центра города является важным параметром для формирования цены на недвижимость. Чем более приближен объект к центру города тем цена на него выше.
#
# Из проделанного анализа данных на рыночную стоимость объектов недвижимости оказывают сильное влияние два параметра это расположение обьекта, удаленность его от центра и площадь объекта.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Супер! Так гораздо лучше)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v2:</b>
# <br>Все правки выполнены. Молодец!
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
